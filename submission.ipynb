# %%
import pandas as pd
import numpy as np
import catboost
import re
import os
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

import joblib

from tqdm._tqdm_notebook import tqdm_notebook
# Out:
# C:\Users\nikit\AppData\Local\Temp\ipykernel_22956\569958320.py:12: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.*` instead of `tqdm._tqdm_notebook.*`
#   from tqdm._tqdm_notebook import tqdm_notebook

# %%
# Считываем данные
tr_mcc_codes = pd.read_csv('mcc_codes.csv', sep=';', index_col='mcc_code')
tr_types = pd.read_csv('trans_types.csv', sep=';', index_col='trans_type')

transactions = pd.read_csv('transactions.csv', index_col='client_id')
gender_train = pd.read_csv('train.csv', index_col='client_id')
gender_test = pd.read_csv('test.csv', index_col='client_id')
transactions_train = transactions.join(gender_train, how='inner')
transactions_test = transactions.join(gender_test, how='inner')
transactions_train = transactions_train.join(tr_mcc_codes, how='inner', on = 'mcc_code')
transactions_test = transactions_test.join(tr_mcc_codes, how='inner', on = 'mcc_code')

# %%
transactions_train.head()
# Out:
#                                     trans_time  mcc_code  trans_type  \
# client_id
# 0002cf30347684df542e1a931f356875  313 14:52:03      4829        2370
# 0002cf30347684df542e1a931f356875  440 22:02:27      4829        2330
# 0002cf30347684df542e1a931f356875  363 07:44:21      4829        2331
# 0002cf30347684df542e1a931f356875  379 11:37:57      4829        2331
# 0002cf30347684df542e1a931f356875  376 18:16:56      4829        2330
#
#                                     amount   term_id        trans_city  \
# client_id
# 0002cf30347684df542e1a931f356875  -2170.07    888990  Saint Petersburg
# 0002cf30347684df542e1a931f356875  -2893.20    800926  Saint Petersburg
# 0002cf30347684df542e1a931f356875  -5011.43  10298153  Saint Petersburg
# 0002cf30347684df542e1a931f356875 -20761.51    980004  Saint Petersburg
# 0002cf30347684df542e1a931f356875 -26032.85    800925  Saint Petersburg
#
#                                   Unnamed: 0  gender    mcc_description
# client_id
# 0002cf30347684df542e1a931f356875        6806       0  Денежные переводы
# 0002cf30347684df542e1a931f356875        6806       0  Денежные переводы
# 0002cf30347684df542e1a931f356875        6806       0  Денежные переводы
# 0002cf30347684df542e1a931f356875        6806       0  Денежные переводы
# 0002cf30347684df542e1a931f356875        6806       0  Денежные переводы

# %%
datasets = [transactions_train, transactions_test]

# %%
for dataset in datasets:
    dataset['earned'] = dataset['amount'] > 0
    dataset['day'] = int(dataset['trans_time'].str.split()[0][0])
    dataset['hour'] = int(dataset['trans_time'].str.split()[1][0].split(':')[0][0])

# %%
def group_by_id(x):
    features = []
    positive = x.loc[x['amount']>0]
    negative = x.loc[x['amount']<0]
    # print(positive.groupby([positive.index, positive['day']])['amount'].agg(['sum', 'std', 'count']).shape)
    features.append(x.groupby([x.index, x['day']])['amount'].agg(['sum', 'std', 'count']).add_prefix('tr_per_day_'))
    features.append(positive.groupby([positive.index, positive['day']])['amount'].agg(['sum', 'std', 'count']).add_prefix('tr_per_day_pos_'))
    features.append(negative.groupby([negative.index, negative['day']])['amount'].agg(['sum', 'std', 'count']).add_prefix('tr_per_day_neg_'))
    features.append(positive.groupby(positive.index)['amount'].agg(['sum', 'count'])\
                                                        .add_prefix('positive_transactions_'))
    features.append(negative.groupby(negative.index)['amount'].agg(['sum', 'count'])\
                                                        .add_prefix('negative_transactions_'))
    features.append(x.groupby(x.index)['amount'].agg(['sum', 'mean', 'std', 'count'])\
                                                        .add_prefix('all_transactions_'))                                                    
    features.append(x.groupby([x.index, 'mcc_code'])['amount'].agg(['sum', 'mean', 'std', 'count'])\
                                                        .add_prefix('mcc_transactions_'))
    features.append(x.groupby([x.index, 'trans_type'])['amount'].agg(['sum', 'mean', 'std', 'count'])\
                                                        .add_prefix('type_transactions_'))
    features.append(negative.groupby(negative.index)['amount'].agg('sum') / positive.groupby(positive.index)['amount'].agg('sum'))
    features.append(pd.get_dummies(data = x,
                                    columns = ['trans_type', 'mcc_code', 'trans_city'], drop_first=True))
    res = pd.concat(features)                                          
    return res.fillna(0, inplace = True)

# %%
for dataset in datasets:
    dataset = group_by_id(dataset)

# %%
complete_train = group_by_id(transactions_train)

# %%
complete_train.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22956\2418923419.py in <module>
# ----> 1 complete_train.head()
#
# AttributeError: 'NoneType' object has no attribute 'head'

# %%
complete_test = group_by_id(transactions_test)
# Out:
# (772, 3)
#                                     trans_time    amount   term_id  \
# client_id
# 002218c52073faaf23bb26df2cffb138   54 10:35:16   -360.78         0
# 002218c52073faaf23bb26df2cffb138   52 11:00:46  -1446.74         0
# 002218c52073faaf23bb26df2cffb138   85 08:23:11  -1446.73         0
# 002218c52073faaf23bb26df2cffb138  344 08:59:29    724.15  10117859
# 002218c52073faaf23bb26df2cffb138  392 13:41:42    722.73  10117859
# ...                                        ...       ...       ...
# e89f8505edcc1828967b118a4a128497  375 23:59:46   -739.43  28560136
# e89f8505edcc1828967b118a4a128497  158 00:00:32 -86230.51         0
# e89f8505edcc1828967b118a4a128497  375 00:00:59  -2546.02  PA03CC06
# e89f8505edcc1828967b118a4a128497  370 23:59:25  -8358.02  PA03CC02
# f11d7a67d566a5a94d8643023a4dc60e  339 11:29:31  -1481.92  500021KP
#
#                                   Unnamed: 0  \
# client_id
# 002218c52073faaf23bb26df2cffb138           0
# 002218c52073faaf23bb26df2cffb138           0
# 002218c52073faaf23bb26df2cffb138           0
# 002218c52073faaf23bb26df2cffb138           0
# 002218c52073faaf23bb26df2cffb138           0
# ...                                      ...
# e89f8505edcc1828967b118a4a128497         753
# e89f8505edcc1828967b118a4a128497         753
# e89f8505edcc1828967b118a4a128497         753
# e89f8505edcc1828967b118a4a128497         753
# f11d7a67d566a5a94d8643023a4dc60e         784
#
#                                                                     mcc_description  \
# client_id
# 002218c52073faaf23bb26df2cffb138  Финансовые институты — снятие наличности автом...
# 002218c52073faaf23bb26df2cffb138  Финансовые институты — снятие наличности автом...
# 002218c52073faaf23bb26df2cffb138  Финансовые институты — снятие наличности автом...
# 002218c52073faaf23bb26df2cffb138  Финансовые институты — снятие наличности автом...
# 002218c52073faaf23bb26df2cffb138  Финансовые институты — снятие наличности автом...
# ...                                                                             ...
# e89f8505edcc1828967b118a4a128497                                 Продажа мотоциклов
# e89f8505edcc1828967b118a4a128497  Промышленное оборудование — нигде более не кла...
# e89f8505edcc1828967b118a4a128497  Промышленное оборудование — нигде более не кла...
# e89f8505edcc1828967b118a4a128497  Промышленное оборудование — нигде более не кла...
# f11d7a67d566a5a94d8643023a4dc60e          Агенты и менеджеры по аренде недвижимости
#
#                                   earned  day  hour  trans_type_1000  \
# client_id
# 002218c52073faaf23bb26df2cffb138   False   54     5                0
# 002218c52073faaf23bb26df2cffb138   False   54     5                0
# 002218c52073faaf23bb26df2cffb138   False   54     5                0
# 002218c52073faaf23bb26df2cffb138    True   54     5                0
# 002218c52073faaf23bb26df2cffb138    True   54     5                0
# ...                                  ...  ...   ...              ...
# e89f8505edcc1828967b118a4a128497   False   54     5                0
# e89f8505edcc1828967b118a4a128497   False   54     5                0
# e89f8505edcc1828967b118a4a128497   False   54     5                0
# e89f8505edcc1828967b118a4a128497   False   54     5                0
# f11d7a67d566a5a94d8643023a4dc60e   False   54     5                0
#
#                                   trans_type_1010  ...  \
# client_id                                          ...
# 002218c52073faaf23bb26df2cffb138                0  ...
# 002218c52073faaf23bb26df2cffb138                0  ...
# 002218c52073faaf23bb26df2cffb138                0  ...
# 002218c52073faaf23bb26df2cffb138                0  ...
# 002218c52073faaf23bb26df2cffb138                0  ...
# ...                                           ...  ...
# e89f8505edcc1828967b118a4a128497                0  ...
# e89f8505edcc1828967b118a4a128497                0  ...
# e89f8505edcc1828967b118a4a128497                0  ...
# e89f8505edcc1828967b118a4a128497                0  ...
# f11d7a67d566a5a94d8643023a4dc60e                0  ...
#
#                                   trans_city_Kaliningrad  trans_city_Kazan  \
# client_id
# 002218c52073faaf23bb26df2cffb138                       0                 0
# 002218c52073faaf23bb26df2cffb138                       0                 0
# 002218c52073faaf23bb26df2cffb138                       0                 0
# 002218c52073faaf23bb26df2cffb138                       0                 0
# 002218c52073faaf23bb26df2cffb138                       0                 0
# ...                                                  ...               ...
# e89f8505edcc1828967b118a4a128497                       0                 0
# e89f8505edcc1828967b118a4a128497                       0                 0
# e89f8505edcc1828967b118a4a128497                       0                 0
# e89f8505edcc1828967b118a4a128497                       0                 0
# f11d7a67d566a5a94d8643023a4dc60e                       0                 0
#
#                                   trans_city_Khabarovsk  trans_city_Moscow  \
# client_id
# 002218c52073faaf23bb26df2cffb138                      0                  0
# 002218c52073faaf23bb26df2cffb138                      0                  0
# 002218c52073faaf23bb26df2cffb138                      0                  0
# 002218c52073faaf23bb26df2cffb138                      0                  0
# 002218c52073faaf23bb26df2cffb138                      0                  0
# ...                                                 ...                ...
# e89f8505edcc1828967b118a4a128497                      0                  0
# e89f8505edcc1828967b118a4a128497                      0                  0
# e89f8505edcc1828967b118a4a128497                      0                  0
# e89f8505edcc1828967b118a4a128497                      0                  0
# f11d7a67d566a5a94d8643023a4dc60e                      0                  0
#
#                                   trans_city_Novosibirsk  trans_city_Penza  \
# client_id
# 002218c52073faaf23bb26df2cffb138                       0                 0
# 002218c52073faaf23bb26df2cffb138                       0                 0
# 002218c52073faaf23bb26df2cffb138                       0                 0
# 002218c52073faaf23bb26df2cffb138                       0                 0
# 002218c52073faaf23bb26df2cffb138                       0                 0
# ...                                                  ...               ...
# e89f8505edcc1828967b118a4a128497                       1                 0
# e89f8505edcc1828967b118a4a128497                       1                 0
# e89f8505edcc1828967b118a4a128497                       1                 0
# e89f8505edcc1828967b118a4a128497                       1                 0
# f11d7a67d566a5a94d8643023a4dc60e                       0                 0
#
#                                   trans_city_Saint Petersburg  \
# client_id
# 002218c52073faaf23bb26df2cffb138                            1
# 002218c52073faaf23bb26df2cffb138                            1
# 002218c52073faaf23bb26df2cffb138                            1
# 002218c52073faaf23bb26df2cffb138                            1
# 002218c52073faaf23bb26df2cffb138                            1
# ...                                                       ...
# e89f8505edcc1828967b118a4a128497                            0
# e89f8505edcc1828967b118a4a128497                            0
# e89f8505edcc1828967b118a4a128497                            0
# e89f8505edcc1828967b118a4a128497                            0
# f11d7a67d566a5a94d8643023a4dc60e                            0
#
#                                   trans_city_Tver  trans_city_Vladimir  \
# client_id
# 002218c52073faaf23bb26df2cffb138                0                    0
# 002218c52073faaf23bb26df2cffb138                0                    0
# 002218c52073faaf23bb26df2cffb138                0                    0
# 002218c52073faaf23bb26df2cffb138                0                    0
# 002218c52073faaf23bb26df2cffb138                0                    0
# ...                                           ...                  ...
# e89f8505edcc1828967b118a4a128497                0                    0
# e89f8505edcc1828967b118a4a128497                0                    0
# e89f8505edcc1828967b118a4a128497                0                    0
# e89f8505edcc1828967b118a4a128497                0                    0
# f11d7a67d566a5a94d8643023a4dc60e                0                    1
#
#                                   trans_city_Vladivostok
# client_id
# 002218c52073faaf23bb26df2cffb138                       0
# 002218c52073faaf23bb26df2cffb138                       0
# 002218c52073faaf23bb26df2cffb138                       0
# 002218c52073faaf23bb26df2cffb138                       0
# 002218c52073faaf23bb26df2cffb138                       0
# ...                                                  ...
# e89f8505edcc1828967b118a4a128497                       0
# e89f8505edcc1828967b118a4a128497                       0
# e89f8505edcc1828967b118a4a128497                       0
# e89f8505edcc1828967b118a4a128497                       0
# f11d7a67d566a5a94d8643023a4dc60e                       0
#
# [324797 rows x 266 columns]

# %%
complete_test.head()
# Out:
#                                         tr_per_day_sum  tr_per_day_std  \
# (002218c52073faaf23bb26df2cffb138, 54)       -76968.86     1872.053451
# (0069d4050c7aeb341317e2e125e8fd2e, 54)      -170516.24     2211.220425
# (0083fb89aea18c408a5534cdd38d7692, 54)       -98003.78     9213.845832
# (014021fa559786c81e9e1d48d378aabb, 54)      -327453.37     2789.158555
# (01759f92152bbb3de79f9493a4a5cd6d, 54)       -51049.00     2602.015856
#
#                                         tr_per_day_count  tr_per_day_pos_sum  \
# (002218c52073faaf23bb26df2cffb138, 54)             124.0                 0.0
# (0069d4050c7aeb341317e2e125e8fd2e, 54)             267.0                 0.0
# (0083fb89aea18c408a5534cdd38d7692, 54)             355.0                 0.0
# (014021fa559786c81e9e1d48d378aabb, 54)             553.0                 0.0
# (01759f92152bbb3de79f9493a4a5cd6d, 54)             300.0                 0.0
#
#                                         tr_per_day_pos_std  \
# (002218c52073faaf23bb26df2cffb138, 54)                 0.0
# (0069d4050c7aeb341317e2e125e8fd2e, 54)                 0.0
# (0083fb89aea18c408a5534cdd38d7692, 54)                 0.0
# (014021fa559786c81e9e1d48d378aabb, 54)                 0.0
# (01759f92152bbb3de79f9493a4a5cd6d, 54)                 0.0
#
#                                         tr_per_day_pos_count  \
# (002218c52073faaf23bb26df2cffb138, 54)                   0.0
# (0069d4050c7aeb341317e2e125e8fd2e, 54)                   0.0
# (0083fb89aea18c408a5534cdd38d7692, 54)                   0.0
# (014021fa559786c81e9e1d48d378aabb, 54)                   0.0
# (01759f92152bbb3de79f9493a4a5cd6d, 54)                   0.0
#
#                                         tr_per_day_neg_sum  \
# (002218c52073faaf23bb26df2cffb138, 54)                 0.0
# (0069d4050c7aeb341317e2e125e8fd2e, 54)                 0.0
# (0083fb89aea18c408a5534cdd38d7692, 54)                 0.0
# (014021fa559786c81e9e1d48d378aabb, 54)                 0.0
# (01759f92152bbb3de79f9493a4a5cd6d, 54)                 0.0
#
#                                         tr_per_day_neg_std  \
# (002218c52073faaf23bb26df2cffb138, 54)                 0.0
# (0069d4050c7aeb341317e2e125e8fd2e, 54)                 0.0
# (0083fb89aea18c408a5534cdd38d7692, 54)                 0.0
# (014021fa559786c81e9e1d48d378aabb, 54)                 0.0
# (01759f92152bbb3de79f9493a4a5cd6d, 54)                 0.0
#
#                                         tr_per_day_neg_count  \
# (002218c52073faaf23bb26df2cffb138, 54)                   0.0
# (0069d4050c7aeb341317e2e125e8fd2e, 54)                   0.0
# (0083fb89aea18c408a5534cdd38d7692, 54)                   0.0
# (014021fa559786c81e9e1d48d378aabb, 54)                   0.0
# (01759f92152bbb3de79f9493a4a5cd6d, 54)                   0.0
#
#                                         positive_transactions_sum  ...  \
# (002218c52073faaf23bb26df2cffb138, 54)                        0.0  ...
# (0069d4050c7aeb341317e2e125e8fd2e, 54)                        0.0  ...
# (0083fb89aea18c408a5534cdd38d7692, 54)                        0.0  ...
# (014021fa559786c81e9e1d48d378aabb, 54)                        0.0  ...
# (01759f92152bbb3de79f9493a4a5cd6d, 54)                        0.0  ...
#
#                                         mcc_code_9402  trans_city_Kazan  \
# (002218c52073faaf23bb26df2cffb138, 54)            0.0               0.0
# (0069d4050c7aeb341317e2e125e8fd2e, 54)            0.0               0.0
# (0083fb89aea18c408a5534cdd38d7692, 54)            0.0               0.0
# (014021fa559786c81e9e1d48d378aabb, 54)            0.0               0.0
# (01759f92152bbb3de79f9493a4a5cd6d, 54)            0.0               0.0
#
#                                         trans_city_Khabarovsk  \
# (002218c52073faaf23bb26df2cffb138, 54)                    0.0
# (0069d4050c7aeb341317e2e125e8fd2e, 54)                    0.0
# (0083fb89aea18c408a5534cdd38d7692, 54)                    0.0
# (014021fa559786c81e9e1d48d378aabb, 54)                    0.0
# (01759f92152bbb3de79f9493a4a5cd6d, 54)                    0.0
#
#                                         trans_city_Moscow  \
# (002218c52073faaf23bb26df2cffb138, 54)                0.0
# (0069d4050c7aeb341317e2e125e8fd2e, 54)                0.0
# (0083fb89aea18c408a5534cdd38d7692, 54)                0.0
# (014021fa559786c81e9e1d48d378aabb, 54)                0.0
# (01759f92152bbb3de79f9493a4a5cd6d, 54)                0.0
#
#                                         trans_city_Novosibirsk  \
# (002218c52073faaf23bb26df2cffb138, 54)                     0.0
# (0069d4050c7aeb341317e2e125e8fd2e, 54)                     0.0
# (0083fb89aea18c408a5534cdd38d7692, 54)                     0.0
# (014021fa559786c81e9e1d48d378aabb, 54)                     0.0
# (01759f92152bbb3de79f9493a4a5cd6d, 54)                     0.0
#
#                                         trans_city_Penza  \
# (002218c52073faaf23bb26df2cffb138, 54)               0.0
# (0069d4050c7aeb341317e2e125e8fd2e, 54)               0.0
# (0083fb89aea18c408a5534cdd38d7692, 54)               0.0
# (014021fa559786c81e9e1d48d378aabb, 54)               0.0
# (01759f92152bbb3de79f9493a4a5cd6d, 54)               0.0
#
#                                         trans_city_Saint Petersburg  \
# (002218c52073faaf23bb26df2cffb138, 54)                          0.0
# (0069d4050c7aeb341317e2e125e8fd2e, 54)                          0.0
# (0083fb89aea18c408a5534cdd38d7692, 54)                          0.0
# (014021fa559786c81e9e1d48d378aabb, 54)                          0.0
# (01759f92152bbb3de79f9493a4a5cd6d, 54)                          0.0
#
#                                         trans_city_Tver  trans_city_Vladimir  \
# (002218c52073faaf23bb26df2cffb138, 54)              0.0                  0.0
# (0069d4050c7aeb341317e2e125e8fd2e, 54)              0.0                  0.0
# (0083fb89aea18c408a5534cdd38d7692, 54)              0.0                  0.0
# (014021fa559786c81e9e1d48d378aabb, 54)              0.0                  0.0
# (01759f92152bbb3de79f9493a4a5cd6d, 54)              0.0                  0.0
#
#                                         trans_city_Vladivostok
# (002218c52073faaf23bb26df2cffb138, 54)                     0.0
# (0069d4050c7aeb341317e2e125e8fd2e, 54)                     0.0
# (0083fb89aea18c408a5534cdd38d7692, 54)                     0.0
# (014021fa559786c81e9e1d48d378aabb, 54)                     0.0
# (01759f92152bbb3de79f9493a4a5cd6d, 54)                     0.0
#
# [5 rows x 289 columns]
